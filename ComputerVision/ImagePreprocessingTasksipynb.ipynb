# %%
import cv2
import numpy as np

# %% [markdown]
# ## Task 1: Image Thresholding Techniques

# %%
# Convert a grayscale image into a binary image using different thresholding methods in OpenCV.

grayimg=cv2.imread('imgs')
